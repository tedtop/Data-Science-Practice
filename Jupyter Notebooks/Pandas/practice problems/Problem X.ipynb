# 2000  411.195289   387.992539         51.883353  7327.593209
# 2001  400.209078   378.076884         58.618698  7219.162974
# 2002  401.730691   375.286669         59.763735  7259.157149
# 2003  417.965117   393.728943         62.831546  7313.828082
# 2004  415.777828   381.852435         64.492951  7428.447645
# 2005  405.442432   371.015529         63.708126  7434.827939
# 2006  391.901762   334.309400         61.066452  7360.801267
# 2007  405.856004   355.254855         57.915315  7463.786408
# 2008  413.166512   363.906982         45.964359  7240.643548
# 2009  416.903785   354.545147         42.460418  6787.264726
# 2010  419.290316   355.539184         36.571398  7007.442261
# 2011  415.067661   349.093809         34.510309  6845.087119
# 2012  396.025010   306.943124         34.364232  6606.523764
# 2013  419.341960   357.731086         28.868748  6784.494217
# 2014  429.600526   378.276992         28.877428  6843.355823
# 2015  442.084720   351.469522         29.207855  6689.006127
# 2016  426.906642   327.812635         26.832725  6537.871031
# 2017  428.486050   329.880970         25.810808  6500.975386
# 2018  444.233499   377.368858         25.794830  6687.512573
# 2019  452.139788   384.178158         24.593554  6571.725747
# 2020  425.312514   361.952257         22.987685  5981.354372

# %% [markdown]
# Plot the total annual US greenhouse gas emission.

# %%
df['Total'].plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# Plot the annual greenhouse gas emissions by sector (transportation, electricity generation, industry, etc).
# Use a **stacked area plot**.
# [Reference page](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.area.html) for `plot.area()`

# %%
df.drop(columns='Total').plot.area(stacked=True)
plt.title('Annual Greenhouse Gas Emissions by Sector')
plt.xlabel('Year')
plt.ylabel('Emissions (million metric tons of CO2 equivalent)')
plt.legend(loc='lower center')
plt.show()

# %% [markdown]
# ### Part 2: Sources of US Energy

# %% [markdown]
# The file *energy_production.csv* contains recent and historical energy production by sector (Coal, Nuclear, Solar, Wind, etc) in quads (one quad is about $10^{18}$ joules).

# %%
path = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Practice/master/Data/energy_production.csv'
df = pd.read_csv(path)
df
# Out:
#      Year      Value                     Sector
# 0    1949  11.973882            Coal Production
# 1    1950  14.060135            Coal Production
# 2    1951  14.419325            Coal Production
# 3    1952  12.734313            Coal Production
# 4    1953  12.277746            Coal Production
# ..    ...        ...                        ...
# 725  2017   5.165726  Biomass Energy Production
# 726  2018   5.314165  Biomass Energy Production
# 727  2019   5.215023  Biomass Energy Production
# 728  2020   4.804830  Biomass Energy Production
# 729  2021   4.997672  Biomass Energy Production
#
# [730 rows x 3 columns]

# %% [markdown]
# Plot the total annual US energy production.

# %%
total_annual_production = df.groupby('Year')['Value'].sum()
total_annual_production.plot()
plt.title('Total Annual US Energy Production')
plt.xlabel('Year')
plt.ylabel('Energy Production (quads)')
plt.show()

# %% [markdown]
# Plot the total annual US energy production by sector.
# Use a **stacked area plot**.

# %%
df.pivot(index='Year', columns='Sector', values='Value').plot.area(stacked=True)
plt.title('Total Annual US Energy Production by Sector')
plt.xlabel('Year')
plt.ylabel('Energy Production (quads)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
